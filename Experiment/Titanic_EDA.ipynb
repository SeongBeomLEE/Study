# %% [markdown]
# 컨셉: 효과적인 결측치 채우기 + 효과적인 변수 생성 -> 효과적인 데이터의 Embedding 생성
#
# - Name -> Age 의 결측치 채우기
# - Name 또한 좋은 변수가 되지 않을까?
#
#
# - Pclass -> Cabin 과 연관성이 존재
# - Fare -> Pclass 와 연관성이 존재
# - Fare + Pclass 로 Cabin의 결측치 채우기
#
#
# - 지금 텍스트 같은 범주형 변수가 매우 많은데 이 변수들을 효과적으로 인코딩 하는 방법이 없을까?
# - Embedding or one-hot encoding or label encoding
# - Data의 열을 Word2Vec(CBOW, 주변단어가 주어졌으 떼 해당 단어가 발생할 획률을 최대화 함)으로 임베딩 한 뒤에 이름의 임베딩을 활용하면 각 사람들의 차원을 구할 수 있을 것이다 <- 결측치를 채워 나간 이유가 지금과 같은 작업을 하려고 였음 (난 사람들의 임베딩을 구하고 싶어)

# %%
import pandas as pd
import numpy as np
import seaborn as sns

import matplotlib as mpl
import matplotlib.pyplot as plt

data_dir = '/content/drive/MyDrive/kaggle study/Data/'
model_dir = '/content/drive/MyDrive/kaggle study/Model/'

# %%
train_df = pd.read_csv(data_dir + 'train.csv')
test_df = pd.read_csv(data_dir + 'test.csv')

# %% [markdown]
# ## 결측치 확인

# %%
def get_missing_value_img(df, title = 'train data missing value img'):
    missing_value_mat = df.isna().astype(int).values

    xticks_li = [i for i in range(len(missing_value_mat[0]))]
    xticklabels_li = df.columns.tolist()

    fig, ax = plt.subplots(1,1, figsize=(13, 13))

    ax.imshow(missing_value_mat, cmap='gray', interpolation='nearest', aspect='auto')

    ax.set_title('train data missing value img')

    ax.set_xticks(xticks_li)

    ax.set_xticklabels(xticklabels_li)

    plt.show()

# %%
train_df.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
get_missing_value_img(df = train_df, title = 'train data missing value img')

# %%
test_df.isna().sum()
# Out:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
get_missing_value_img(df = test_df, title = 'test data missing value img')

# %% [markdown]
# ## Survived + 연속형 변수

# %%
sns.violinplot(data = train_df, x = 'Survived', y = 'Fare')
plt.title('Survived and Fare')
plt.show()

# %%
'''
50 달러씩 나눔
'''

fig, ax = plt.subplots(1,1, figsize=(8, 8))

ax.set_xticks([i for i in range(0, 511, 50)])
ax = sns.histplot(data = train_df, x = 'Fare', hue = 'Survived', bins = 10, ax = ax)
plt.show()

# %%
'''
25 달러씩 나눔
'''

fig, ax = plt.subplots(1,1, figsize=(8, 8))

ax.set_xticks([i for i in range(0, 511, 25)])
ax = sns.histplot(data = train_df, x = 'Fare', hue = 'Survived', bins = 20, ax = ax)
plt.show()

# %%
sns.violinplot(data = train_df, x = 'Survived', y = 'Age')
plt.title('Survived and Age')
plt.show()

# %%
'''
4살씩
'''
sns.histplot(data = train_df, x = 'Age', hue = 'Survived', bins = 20)

# %%
'''
8살씩
'''
sns.histplot(data = train_df, x = 'Age', hue = 'Survived', bins = 10)

# %%
'''
10살씩
'''
sns.histplot(data = train_df, x = 'Age', hue = 'Survived', bins = 8)

# %% [markdown]
# ## Survived + 이산형 변수

# %%
sns.countplot(data = train_df, x = 'Pclass', hue = 'Survived')

# %%
sns.countplot(data = train_df, x = 'Sex', hue = 'Survived')

# %%
sns.countplot(data = train_df, x = 'SibSp', hue = 'Survived')

# %%
sns.countplot(data = train_df, x = 'Parch', hue = 'Survived')

# %%
sns.countplot(data = train_df, x = 'Embarked', hue = 'Survived')

# %% [markdown]
# ## 이름 정보로 Age 결측치 채우기

# %%
def get_new_Name(x):
    x = x.split(', ')[1]
    x = x.split('.')[0]
    return x

train_df['new_Name'] = train_df['Name'].apply(lambda x : get_new_Name(x))
test_df['new_Name'] = test_df['Name'].apply(lambda x : get_new_Name(x))

# %%
fig, ax = plt.subplots(1,1, figsize=(13, 13))

sns.violinplot(data = train_df, x = 'new_Name', y = 'Age', ax = ax)
plt.title('new_Name and Age')
plt.show()

# %%
new_Name2Age = {}
for new_Name, Age in zip(train_df.groupby('new_Name').mean()['Age'].index, train_df.groupby('new_Name').mean()['Age'].values):
    new_Name2Age[new_Name] = Age

def get_new_Age(df):
    if pd.isna(df['Age']):
        return new_Name2Age[df['new_Name']]
    else:
        return df['Age']

train_df['new_Age'] = train_df.apply(lambda x : get_new_Age(x), axis = 1)
test_df['new_Age'] = test_df.apply(lambda x : get_new_Age(x), axis = 1)

# %% [markdown]
# # Fare + Pclass를 이용한 Cabin 결측치 채우기

# %%
def get_new_Cabin(x):
    if pd.isna(x): return x
    else: return str(x)[:1]

train_df['new_Cabin'] = train_df['Cabin'].apply(lambda x : get_new_Cabin(x))

# %%
sns.violinplot(data = train_df, y = 'Fare', x = 'new_Cabin', order = sorted([i for i in train_df['new_Cabin'].unique().tolist() if not pd.isna(i)]))

# %%
sns.countplot(data = train_df, x = 'new_Cabin', hue = 'Pclass', order = sorted([i for i in train_df['new_Cabin'].unique().tolist() if not pd.isna(i)]))

# %%
sns.violinplot(data = train_df, y = 'Fare', x = 'Pclass')

# %% [markdown]
# # 연속형 변수의 범주화
#
# Age = 8살씩
#
# Fare = 50 달러씩

# %%
def get_cat_Age(x):
    if x <= 8: return 0
    elif x <= 16: return 1
    elif x <= 24: return 2
    elif x <= 32: return 3
    elif x <= 40: return 4
    elif x <= 48: return 5
    elif x <= 56: return 6
    elif x <= 64: return 7
    elif x <= 72: return 8
    elif x <= 80: return 9
    else: return 10

def get_cat_Fare(x):
    if x <= 50: return 0
    elif x <= 100: return 1
    elif x <= 150: return 2
    elif x <= 200: return 3
    elif x <= 250: return 4
    elif x <= 300: return 5
    elif x <= 350: return 6
    elif x <= 400: return 7
    elif x <= 450: return 8
    elif x <= 500: return 9
    else: return 10


train_df['cat_Pclass'] = 'Pclass' + '_' + train_df['Pclass'].astype(str)
train_df['cat_Sex'] = 'Sex' + '_' + train_df['Sex'].astype(str)
train_df['cat_Age'] = 'Age' + '_' + train_df['new_Age'].apply(lambda x: get_cat_Age(x)).astype(str)
train_df['cat_SibSp'] = 'SibSp' + '_' + train_df['SibSp'].astype(str)
train_df['cat_Parch'] = 'Parch' + '_' + train_df['Parch'].astype(str)
train_df['cat_Fare'] = 'Fare' + '_' + train_df['Fare'].apply(lambda x: get_cat_Fare(x)).astype(str)
values = {'Embarked' : 'S'}
train_df['cat_Embarked'] = 'Embarked' + '_' + train_df.fillna(value = values)['Embarked'].astype(str)
train_df['cat_Name'] = train_df['PassengerId'].astype(str) + '_' + train_df['Name'].astype(str)

test_df['cat_Pclass'] = 'Pclass' + '_' + test_df['Pclass'].astype(str)
test_df['cat_Sex'] = 'Sex' + '_' + test_df['Sex'].astype(str)
test_df['cat_Age'] = 'Age' + '_' + test_df['new_Age'].apply(lambda x: get_cat_Age(x)).astype(str)
test_df['cat_SibSp'] = 'SibSp' + '_' + test_df['SibSp'].astype(str)
test_df['cat_Parch'] = 'Parch' + '_' + test_df['Parch'].astype(str)
values = {'Fare' : 55}
test_df['cat_Fare'] = 'Fare' + '_' + test_df.fillna(value = values)['Fare'].apply(lambda x: get_cat_Fare(x)).astype(str)
test_df['cat_Embarked'] = 'Embarked' + '_' + test_df.fillna(value = values)['Embarked'].astype(str)
test_df['cat_Name'] = test_df['PassengerId'].astype(str) + '_' + test_df['Name'].astype(str)

# %% [markdown]
# # Name의 임베딩화

# %%
cols = [col for col in train_df.columns if 'cat' in col]

# %%
sentences = train_df[cols].values.tolist() + test_df[cols].values.tolist()

# %%
from gensim.models import Word2Vec
from gensim.models.word2vec import LineSentence
from gensim.models.callbacks import CallbackAny2Vec
import datetime

class callback(CallbackAny2Vec):
    '''Callback to print loss after each epoch.'''

    def __init__(self):
        self.epoch = 1
        self.loss_to_be_subed = 0
        self.loss_now = 987654321

    def on_epoch_end(self, model):
        loss = model.get_latest_training_loss()
        loss_now = loss - self.loss_to_be_subed
        print(f'Loss after epoch {self.epoch}: {loss_now}, Total_loss : {loss}')

        self.loss_to_be_subed = loss
        if loss_now < self.loss_now:
            self.loss_now = loss_now
            model.save(model_dir + 'Word2Vec_Embedding_Model.model')
            print('Model 저장')
        self.epoch += 1

start = datetime.datetime.now()

model = Word2Vec(
                sentences = sentences,
                seed = 0,
                iter = 500,
                min_count = 1,
                size = 50,
                sg = 0,
                negative = 1,
                window = 100,
                compute_loss=True, 
                callbacks=[callback()],
                 )

print("Time passed: " + str(datetime.datetime.now() - start))
# Out:
# Loss after epoch 1: 4144.50341796875, Total_loss : 4144.50341796875
# Model 저장
# Loss after epoch 2: 4113.47998046875, Total_loss : 8257.9833984375
# Model 저장
# Loss after epoch 3: 4076.240234375, Total_loss : 12334.2236328125
# Model 저장
# Loss after epoch 4: 4140.0439453125, Total_loss : 16474.267578125
# Loss after epoch 5: 4086.970703125, Total_loss : 20561.23828125
# Loss after epoch 6: 4175.0859375, Total_loss : 24736.32421875
# Loss after epoch 7: 4047.42578125, Total_loss : 28783.75
# Model 저장
# Loss after epoch 8: 4060.265625, Total_loss : 32844.015625
# Loss after epoch 9: 4134.0234375, Total_loss : 36978.0390625
# Loss after epoch 10: 4135.74609375, Total_loss : 41113.78515625
# Loss after epoch 11: 4177.515625, Total_loss : 45291.30078125
# Loss after epoch 12: 4136.47265625, Total_loss : 49427.7734375
# Loss after epoch 13: 4032.21484375, Total_loss : 53459.98828125
# Model 저장
# Loss after epoch 14: 4109.6015625, Total_loss : 57569.58984375
# Loss after epoch 15: 4070.78125, Total_loss : 61640.37109375
# Loss after epoch 16: 4084.75390625, Total_loss : 65725.125
# Loss after epoch 17: 4225.0703125, Total_loss : 69950.1953125
# Loss after epoch 18: 4056.9296875, Total_loss : 74007.125
# Loss after epoch 19: 4096.7734375, Total_loss : 78103.8984375
# Loss after epoch 20: 4067.5625, Total_loss : 82171.4609375
# Loss after epoch 21: 4070.8203125, Total_loss : 86242.28125
# Loss after epoch 22: 4088.6328125, Total_loss : 90330.9140625
# Loss after epoch 23: 4105.1640625, Total_loss : 94436.078125
# Loss after epoch 24: 3959.765625, Total_loss : 98395.84375
# Model 저장
# Loss after epoch 25: 201.890625, Total_loss : 98597.734375
# Model 저장
# Loss after epoch 26: 4108.015625, Total_loss : 102705.75
# Loss after epoch 27: 3952.28125, Total_loss : 106658.03125
# Loss after epoch 28: 4076.2578125, Total_loss : 110734.2890625
# Loss after epoch 29: 3993.1875, Total_loss : 114727.4765625
# Loss after epoch 30: 4048.8671875, Total_loss : 118776.34375
# Loss after epoch 31: 4099.546875, Total_loss : 122875.890625
# Loss after epoch 32: 4046.2421875, Total_loss : 126922.1328125
# Loss after epoch 33: 4009.1796875, Total_loss : 130931.3125
# Loss after epoch 34: 3944.125, Total_loss : 134875.4375
# Loss after epoch 35: 4042.40625, Total_loss : 138917.84375
# Loss after epoch 36: 3975.390625, Total_loss : 142893.234375
# Loss after epoch 37: 3939.609375, Total_loss : 146832.84375
# Loss after epoch 38: 3973.046875, Total_loss : 150805.890625
# Loss after epoch 39: 3912.5, Total_loss : 154718.390625
# Loss after epoch 40: 4093.125, Total_loss : 158811.515625
# Loss after epoch 41: 3866.828125, Total_loss : 162678.34375
# Loss after epoch 42: 4149.3125, Total_loss : 166827.65625
# Loss after epoch 43: 3883.765625, Total_loss : 170711.421875
# Loss after epoch 44: 3909.078125, Total_loss : 174620.5
# Loss after epoch 45: 3842.140625, Total_loss : 178462.640625
# Loss after epoch 46: 3802.5625, Total_loss : 182265.203125
# Loss after epoch 47: 3848.625, Total_loss : 186113.828125
# Loss after epoch 48: 3785.90625, Total_loss : 189899.734375
# Loss after epoch 49: 3845.140625, Total_loss : 193744.875
# Loss after epoch 50: 3742.46875, Total_loss : 197487.34375
# Loss after epoch 51: 3843.46875, Total_loss : 201330.8125
# Loss after epoch 52: 3787.5625, Total_loss : 205118.375
# Loss after epoch 53: 3754.796875, Total_loss : 208873.171875
# Loss after epoch 54: 3658.953125, Total_loss : 212532.125
# Loss after epoch 55: 3697.046875, Total_loss : 216229.171875
# Loss after epoch 56: 3684.34375, Total_loss : 219913.515625
# Loss after epoch 57: 3694.0, Total_loss : 223607.515625
# Loss after epoch 58: 3762.8125, Total_loss : 227370.328125
# Loss after epoch 59: 3694.8125, Total_loss : 231065.140625
# Loss after epoch 60: 3717.421875, Total_loss : 234782.5625
# Loss after epoch 61: 3710.671875, Total_loss : 238493.234375
# Loss after epoch 62: 3685.203125, Total_loss : 242178.4375
# Loss after epoch 63: 3756.859375, Total_loss : 245935.296875
# Loss after epoch 64: 3602.890625, Total_loss : 249538.1875
# Loss after epoch 65: 3646.484375, Total_loss : 253184.671875
# Loss after epoch 66: 3581.40625, Total_loss : 256766.078125
# Loss after epoch 67: 3605.515625, Total_loss : 260371.59375
# Loss after epoch 68: 3609.03125, Total_loss : 263980.625
# Loss after epoch 69: 3624.96875, Total_loss : 267605.59375
# Loss after epoch 70: 3605.78125, Total_loss : 271211.375
# Loss after epoch 71: 3631.25, Total_loss : 274842.625
# Loss after epoch 72: 3779.90625, Total_loss : 278622.53125
# Loss after epoch 73: 148.53125, Total_loss : 278771.0625
# Model 저장
# Loss after epoch 74: 3525.09375, Total_loss : 282296.15625
# Loss after epoch 75: 3532.53125, Total_loss : 285828.6875
# Loss after epoch 76: 3628.40625, Total_loss : 289457.09375
# Loss after epoch 77: 3561.0, Total_loss : 293018.09375
# Loss after epoch 78: 3592.3125, Total_loss : 296610.40625
# Loss after epoch 79: 3600.65625, Total_loss : 300211.0625
# Loss after epoch 80: 3548.59375, Total_loss : 303759.65625
# Loss after epoch 81: 3483.09375, Total_loss : 307242.75
# Loss after epoch 82: 3592.9375, Total_loss : 310835.6875
# Loss after epoch 83: 3504.96875, Total_loss : 314340.65625
# Loss after epoch 84: 3553.46875, Total_loss : 317894.125
# Loss after epoch 85: 3532.15625, Total_loss : 321426.28125
# Loss after epoch 86: 3514.625, Total_loss : 324940.90625
# Loss after epoch 87: 3486.53125, Total_loss : 328427.4375
# Loss after epoch 88: 3529.15625, Total_loss : 331956.59375
# Loss after epoch 89: 3475.28125, Total_loss : 335431.875
# Loss after epoch 90: 3496.28125, Total_loss : 338928.15625
# Loss after epoch 91: 3486.90625, Total_loss : 342415.0625
# Loss after epoch 92: 3443.53125, Total_loss : 345858.59375
# Loss after epoch 93: 3576.53125, Total_loss : 349435.125
# Loss after epoch 94: 3515.125, Total_loss : 352950.25
# Loss after epoch 95: 3506.84375, Total_loss : 356457.09375
# Loss after epoch 96: 3508.0, Total_loss : 359965.09375
# Loss after epoch 97: 3432.28125, Total_loss : 363397.375
# Loss after epoch 98: 3420.03125, Total_loss : 366817.40625
# Loss after epoch 99: 3483.0625, Total_loss : 370300.46875
# Loss after epoch 100: 3433.25, Total_loss : 373733.71875
# Loss after epoch 101: 3545.21875, Total_loss : 377278.9375
# Loss after epoch 102: 3391.375, Total_loss : 380670.3125
# Loss after epoch 103: 3521.34375, Total_loss : 384191.65625
# Loss after epoch 104: 3387.21875, Total_loss : 387578.875
# Loss after epoch 105: 3440.09375, Total_loss : 391018.96875
# Loss after epoch 106: 3462.71875, Total_loss : 394481.6875
# Loss after epoch 107: 3632.5625, Total_loss : 398114.25
# Loss after epoch 108: 164.28125, Total_loss : 398278.53125
# Loss after epoch 109: 3409.15625, Total_loss : 401687.6875
# Loss after epoch 110: 3375.65625, Total_loss : 405063.34375
# Loss after epoch 111: 3423.40625, Total_loss : 408486.75
# Loss after epoch 112: 3424.03125, Total_loss : 411910.78125
# Loss after epoch 113: 3349.75, Total_loss : 415260.53125
# Loss after epoch 114: 3406.0, Total_loss : 418666.53125
# Loss after epoch 115: 3400.84375, Total_loss : 422067.375
# Loss after epoch 116: 3368.375, Total_loss : 425435.75
# Loss after epoch 117: 3363.71875, Total_loss : 428799.46875
# Loss after epoch 118: 3414.875, Total_loss : 432214.34375
# Loss after epoch 119: 3342.40625, Total_loss : 435556.75
# Loss after epoch 120: 3321.21875, Total_loss : 438877.96875
# Loss after epoch 121: 3387.3125, Total_loss : 442265.28125
# Loss after epoch 122: 3328.125, Total_loss : 445593.40625
# Loss after epoch 123: 3423.96875, Total_loss : 449017.375
# Loss after epoch 124: 3424.0, Total_loss : 452441.375
# Loss after epoch 125: 3307.9375, Total_loss : 455749.3125
# Loss after epoch 126: 3354.96875, Total_loss : 459104.28125
# Loss after epoch 127: 3308.8125, Total_loss : 462413.09375
# Loss after epoch 128: 3354.53125, Total_loss : 465767.625
# Loss after epoch 129: 3283.625, Total_loss : 469051.25
# Loss after epoch 130: 3405.40625, Total_loss : 472456.65625
# Loss after epoch 131: 3336.09375, Total_loss : 475792.75
# Loss after epoch 132: 3300.03125, Total_loss : 479092.78125
# Loss after epoch 133: 3403.5, Total_loss : 482496.28125
# Loss after epoch 134: 156.59375, Total_loss : 482652.875
# Loss after epoch 135: 3417.90625, Total_loss : 486070.78125
# Loss after epoch 136: 3268.03125, Total_loss : 489338.8125
# Loss after epoch 137: 3349.59375, Total_loss : 492688.40625
# Loss after epoch 138: 3274.59375, Total_loss : 495963.0
# Loss after epoch 139: 3321.4375, Total_loss : 499284.4375
# Loss after epoch 140: 3329.4375, Total_loss : 502613.875
# Loss after epoch 141: 3250.46875, Total_loss : 505864.34375
# Loss after epoch 142: 3248.375, Total_loss : 509112.71875
# Loss after epoch 143: 3289.09375, Total_loss : 512401.8125
# Loss after epoch 144: 3289.34375, Total_loss : 515691.15625
# Loss after epoch 145: 3392.625, Total_loss : 519083.78125
# Loss after epoch 146: 3242.75, Total_loss : 522326.53125
# Loss after epoch 147: 3293.65625, Total_loss : 525620.1875
# Loss after epoch 148: 3196.5, Total_loss : 528816.6875
# Loss after epoch 149: 3237.5, Total_loss : 532054.1875
# Loss after epoch 150: 3225.5, Total_loss : 535279.6875
# Loss after epoch 151: 3312.4375, Total_loss : 538592.125
# Loss after epoch 152: 3169.1875, Total_loss : 541761.3125
# Loss after epoch 153: 3246.25, Total_loss : 545007.5625
# Loss after epoch 154: 3296.75, Total_loss : 548304.3125
# Loss after epoch 155: 3252.3125, Total_loss : 551556.625
# Loss after epoch 156: 3169.625, Total_loss : 554726.25
# Loss after epoch 157: 3276.5, Total_loss : 558002.75
# Loss after epoch 158: 138.5625, Total_loss : 558141.3125
# Model 저장
# Loss after epoch 159: 3239.6875, Total_loss : 561381.0
# Loss after epoch 160: 3198.0, Total_loss : 564579.0
# Loss after epoch 161: 3192.5, Total_loss : 567771.5
# Loss after epoch 162: 3166.25, Total_loss : 570937.75
# Loss after epoch 163: 3198.125, Total_loss : 574135.875
# Loss after epoch 164: 3161.375, Total_loss : 577297.25
# Loss after epoch 165: 3117.75, Total_loss : 580415.0
# Loss after epoch 166: 3236.0625, Total_loss : 583651.0625
# Loss after epoch 167: 3132.625, Total_loss : 586783.6875
# Loss after epoch 168: 3214.1875, Total_loss : 589997.875
# Loss after epoch 169: 3102.8125, Total_loss : 593100.6875
# Loss after epoch 170: 3176.75, Total_loss : 596277.4375
# Loss after epoch 171: 3189.25, Total_loss : 599466.6875
# Loss after epoch 172: 3152.125, Total_loss : 602618.8125
# Loss after epoch 173: 3141.3125, Total_loss : 605760.125
# Loss after epoch 174: 3163.125, Total_loss : 608923.25
# Loss after epoch 175: 3144.875, Total_loss : 612068.125
# Loss after epoch 176: 3100.3125, Total_loss : 615168.4375
# Loss after epoch 177: 3065.0, Total_loss : 618233.4375
# Loss after epoch 178: 3182.0, Total_loss : 621415.4375
# Loss after epoch 179: 3201.1875, Total_loss : 624616.625
# Loss after epoch 180: 3077.0625, Total_loss : 627693.6875
# Loss after epoch 181: 3134.8125, Total_loss : 630828.5
# Loss after epoch 182: 3096.5, Total_loss : 633925.0
# Loss after epoch 183: 3046.3125, Total_loss : 636971.3125
# Loss after epoch 184: 3092.625, Total_loss : 640063.9375
# Loss after epoch 185: 3105.375, Total_loss : 643169.3125
# Loss after epoch 186: 3049.5, Total_loss : 646218.8125
# Loss after epoch 187: 3141.5, Total_loss : 649360.3125
# Loss after epoch 188: 3117.5, Total_loss : 652477.8125
# Loss after epoch 189: 3038.5, Total_loss : 655516.3125
# Loss after epoch 190: 3067.0, Total_loss : 658583.3125
# Loss after epoch 191: 3176.4375, Total_loss : 661759.75
# Loss after epoch 192: 3143.5625, Total_loss : 664903.3125
# Loss after epoch 193: 3069.75, Total_loss : 667973.0625
# Loss after epoch 194: 3100.1875, Total_loss : 671073.25
# Loss after epoch 195: 159.0, Total_loss : 671232.25
# Loss after epoch 196: 3068.375, Total_loss : 674300.625
# Loss after epoch 197: 3008.9375, Total_loss : 677309.5625
# Loss after epoch 198: 3075.6875, Total_loss : 680385.25
# Loss after epoch 199: 3057.0625, Total_loss : 683442.3125
# Loss after epoch 200: 3057.0, Total_loss : 686499.3125
# Loss after epoch 201: 3054.1875, Total_loss : 689553.5
# Loss after epoch 202: 3031.8125, Total_loss : 692585.3125
# Loss after epoch 203: 3113.75, Total_loss : 695699.0625
# Loss after epoch 204: 137.0625, Total_loss : 695836.125
# Model 저장
# Loss after epoch 205: 3118.1875, Total_loss : 698954.3125
# Loss after epoch 206: 3104.6875, Total_loss : 702059.0
# Loss after epoch 207: 3077.375, Total_loss : 705136.375
# Loss after epoch 208: 2995.375, Total_loss : 708131.75
# Loss after epoch 209: 3068.625, Total_loss : 711200.375
# Loss after epoch 210: 3090.0, Total_loss : 714290.375
# Loss after epoch 211: 3054.75, Total_loss : 717345.125
# Loss after epoch 212: 2975.3125, Total_loss : 720320.4375
# Loss after epoch 213: 3026.875, Total_loss : 723347.3125
# Loss after epoch 214: 2963.75, Total_loss : 726311.0625
# Loss after epoch 215: 2956.5, Total_loss : 729267.5625
# Loss after epoch 216: 2969.5625, Total_loss : 732237.125
# Loss after epoch 217: 2995.5, Total_loss : 735232.625
# Loss after epoch 218: 2943.6875, Total_loss : 738176.3125
# Loss after epoch 219: 2997.5625, Total_loss : 741173.875
# Loss after epoch 220: 3040.625, Total_loss : 744214.5
# Loss after epoch 221: 3010.625, Total_loss : 747225.125
# Loss after epoch 222: 3012.4375, Total_loss : 750237.5625
# Loss after epoch 223: 3026.5625, Total_loss : 753264.125
# Loss after epoch 224: 3025.1875, Total_loss : 756289.3125
# Loss after epoch 225: 2945.125, Total_loss : 759234.4375
# Loss after epoch 226: 2949.375, Total_loss : 762183.8125
# Loss after epoch 227: 2992.75, Total_loss : 765176.5625
# Loss after epoch 228: 2978.0, Total_loss : 768154.5625
# Loss after epoch 229: 2960.0, Total_loss : 771114.5625
# Loss after epoch 230: 2968.375, Total_loss : 774082.9375
# Loss after epoch 231: 3013.375, Total_loss : 777096.3125
# Loss after epoch 232: 2951.125, Total_loss : 780047.4375
# Loss after epoch 233: 2985.875, Total_loss : 783033.3125
# Loss after epoch 234: 2932.375, Total_loss : 785965.6875
# Loss after epoch 235: 2924.375, Total_loss : 788890.0625
# Loss after epoch 236: 2913.4375, Total_loss : 791803.5
# Loss after epoch 237: 2965.375, Total_loss : 794768.875
# Loss after epoch 238: 3058.25, Total_loss : 797827.125
# Loss after epoch 239: 2934.0, Total_loss : 800761.125
# Loss after epoch 240: 2878.875, Total_loss : 803640.0
# Loss after epoch 241: 2984.0625, Total_loss : 806624.0625
# Loss after epoch 242: 2917.375, Total_loss : 809541.4375
# Loss after epoch 243: 2852.375, Total_loss : 812393.8125
# Loss after epoch 244: 2959.9375, Total_loss : 815353.75
# Loss after epoch 245: 2890.1875, Total_loss : 818243.9375
# Loss after epoch 246: 2963.125, Total_loss : 821207.0625
# Loss after epoch 247: 2880.625, Total_loss : 824087.6875
# Loss after epoch 248: 2907.125, Total_loss : 826994.8125
# Loss after epoch 249: 2881.375, Total_loss : 829876.1875
# Loss after epoch 250: 2828.75, Total_loss : 832704.9375
# Loss after epoch 251: 2941.9375, Total_loss : 835646.875
# Loss after epoch 252: 2928.0625, Total_loss : 838574.9375
# Loss after epoch 253: 2858.375, Total_loss : 841433.3125
# Loss after epoch 254: 2917.9375, Total_loss : 844351.25
# Loss after epoch 255: 2912.6875, Total_loss : 847263.9375
# Loss after epoch 256: 2914.75, Total_loss : 850178.6875
# Loss after epoch 257: 2788.875, Total_loss : 852967.5625
# Loss after epoch 258: 2889.125, Total_loss : 855856.6875
# Loss after epoch 259: 2895.1875, Total_loss : 858751.875
# Loss after epoch 260: 2895.6875, Total_loss : 861647.5625
# Loss after epoch 261: 2854.4375, Total_loss : 864502.0
# Loss after epoch 262: 2774.4375, Total_loss : 867276.4375
# Loss after epoch 263: 2827.1875, Total_loss : 870103.625
# Loss after epoch 264: 2844.4375, Total_loss : 872948.0625
# Loss after epoch 265: 2813.25, Total_loss : 875761.3125
# Loss after epoch 266: 2799.625, Total_loss : 878560.9375
# Loss after epoch 267: 2742.5625, Total_loss : 881303.5
# Loss after epoch 268: 2880.25, Total_loss : 884183.75
# Loss after epoch 269: 2899.25, Total_loss : 887083.0
# Loss after epoch 270: 2863.375, Total_loss : 889946.375
# Loss after epoch 271: 2855.6875, Total_loss : 892802.0625
# Loss after epoch 272: 2855.5625, Total_loss : 895657.625
# Loss after epoch 273: 2800.5, Total_loss : 898458.125
# Loss after epoch 274: 2878.3125, Total_loss : 901336.4375
# Loss after epoch 275: 2841.75, Total_loss : 904178.1875
# Loss after epoch 276: 2828.5, Total_loss : 907006.6875
# Loss after epoch 277: 2827.3125, Total_loss : 909834.0
# Loss after epoch 278: 2805.625, Total_loss : 912639.625
# Loss after epoch 279: 2789.875, Total_loss : 915429.5
# Loss after epoch 280: 2807.0, Total_loss : 918236.5
# Loss after epoch 281: 2812.75, Total_loss : 921049.25
# Loss after epoch 282: 2792.3125, Total_loss : 923841.5625
# Loss after epoch 283: 2893.0, Total_loss : 926734.5625
# Loss after epoch 284: 2786.6875, Total_loss : 929521.25
# Loss after epoch 285: 2891.25, Total_loss : 932412.5
# Loss after epoch 286: 2840.3125, Total_loss : 935252.8125
# Loss after epoch 287: 2794.1875, Total_loss : 938047.0
# Loss after epoch 288: 2843.875, Total_loss : 940890.875
# Loss after epoch 289: 2815.0, Total_loss : 943705.875
# Loss after epoch 290: 2859.9375, Total_loss : 946565.8125
# Loss after epoch 291: 2786.3125, Total_loss : 949352.125
# Loss after epoch 292: 2780.5625, Total_loss : 952132.6875
# Loss after epoch 293: 2822.75, Total_loss : 954955.4375
# Loss after epoch 294: 2773.9375, Total_loss : 957729.375
# Loss after epoch 295: 2781.25, Total_loss : 960510.625
# Loss after epoch 296: 2815.0625, Total_loss : 963325.6875
# Loss after epoch 297: 2765.9375, Total_loss : 966091.625
# Loss after epoch 298: 2748.25, Total_loss : 968839.875
# Loss after epoch 299: 2802.125, Total_loss : 971642.0
# Loss after epoch 300: 2773.0625, Total_loss : 974415.0625
# Loss after epoch 301: 2837.8125, Total_loss : 977252.875
# Loss after epoch 302: 2790.9375, Total_loss : 980043.8125
# Loss after epoch 303: 2790.3125, Total_loss : 982834.125
# Loss after epoch 304: 2726.3125, Total_loss : 985560.4375
# Loss after epoch 305: 134.625, Total_loss : 985695.0625
# Model 저장
# Loss after epoch 306: 2806.375, Total_loss : 988501.4375
# Loss after epoch 307: 2820.0, Total_loss : 991321.4375
# Loss after epoch 308: 2777.75, Total_loss : 994099.1875
# Loss after epoch 309: 2785.125, Total_loss : 996884.3125
# Loss after epoch 310: 2700.875, Total_loss : 999585.1875
# Loss after epoch 311: 2696.75, Total_loss : 1002281.9375
# Loss after epoch 312: 2786.625, Total_loss : 1005068.5625
# Loss after epoch 313: 2749.3125, Total_loss : 1007817.875
# Loss after epoch 314: 2746.375, Total_loss : 1010564.25
# Loss after epoch 315: 2730.375, Total_loss : 1013294.625
# Loss after epoch 316: 2759.125, Total_loss : 1016053.75
# Loss after epoch 317: 2768.0625, Total_loss : 1018821.8125
# Loss after epoch 318: 2632.625, Total_loss : 1021454.4375
# Loss after epoch 319: 2792.5, Total_loss : 1024246.9375
# Loss after epoch 320: 2733.625, Total_loss : 1026980.5625
# Loss after epoch 321: 2754.1875, Total_loss : 1029734.75
# Loss after epoch 322: 2728.1875, Total_loss : 1032462.9375
# Loss after epoch 323: 2709.125, Total_loss : 1035172.0625
# Loss after epoch 324: 2726.5625, Total_loss : 1037898.625
# Loss after epoch 325: 2770.8125, Total_loss : 1040669.4375
# Loss after epoch 326: 2707.0625, Total_loss : 1043376.5
# Loss after epoch 327: 2671.25, Total_loss : 1046047.75
# Loss after epoch 328: 2732.0, Total_loss : 1048779.75
# Loss after epoch 329: 2777.875, Total_loss : 1051557.625
# Loss after epoch 330: 2748.125, Total_loss : 1054305.75
# Loss after epoch 331: 2831.375, Total_loss : 1057137.125
# Loss after epoch 332: 2694.5, Total_loss : 1059831.625
# Loss after epoch 333: 2732.25, Total_loss : 1062563.875
# Loss after epoch 334: 2753.75, Total_loss : 1065317.625
# Loss after epoch 335: 2778.125, Total_loss : 1068095.75
# Loss after epoch 336: 2766.0, Total_loss : 1070861.75
# Loss after epoch 337: 2749.375, Total_loss : 1073611.125
# Loss after epoch 338: 2781.625, Total_loss : 1076392.75
# Loss after epoch 339: 2703.75, Total_loss : 1079096.5
# Loss after epoch 340: 2719.25, Total_loss : 1081815.75
# Loss after epoch 341: 2746.0, Total_loss : 1084561.75
# Loss after epoch 342: 2708.125, Total_loss : 1087269.875
# Loss after epoch 343: 2791.75, Total_loss : 1090061.625
# Loss after epoch 344: 2712.625, Total_loss : 1092774.25
# Loss after epoch 345: 2707.875, Total_loss : 1095482.125
# Loss after epoch 346: 2714.625, Total_loss : 1098196.75
# Loss after epoch 347: 2661.25, Total_loss : 1100858.0
# Loss after epoch 348: 2638.5, Total_loss : 1103496.5
# Loss after epoch 349: 2650.0, Total_loss : 1106146.5
# Loss after epoch 350: 2665.625, Total_loss : 1108812.125
# Loss after epoch 351: 2684.375, Total_loss : 1111496.5
# Loss after epoch 352: 134.875, Total_loss : 1111631.375
# Loss after epoch 353: 2860.5, Total_loss : 1114491.875
# Loss after epoch 354: 2650.375, Total_loss : 1117142.25
# Loss after epoch 355: 2669.0, Total_loss : 1119811.25
# Loss after epoch 356: 2750.0, Total_loss : 1122561.25
# Loss after epoch 357: 2679.0, Total_loss : 1125240.25
# Loss after epoch 358: 2651.25, Total_loss : 1127891.5
# Loss after epoch 359: 2672.625, Total_loss : 1130564.125
# Loss after epoch 360: 2780.0, Total_loss : 1133344.125
# Loss after epoch 361: 2637.375, Total_loss : 1135981.5
# Loss after epoch 362: 2686.875, Total_loss : 1138668.375
# Loss after epoch 363: 2690.125, Total_loss : 1141358.5
# Loss after epoch 364: 2742.875, Total_loss : 1144101.375
# Loss after epoch 365: 2720.5, Total_loss : 1146821.875
# Loss after epoch 366: 2725.375, Total_loss : 1149547.25
# Loss after epoch 367: 2719.375, Total_loss : 1152266.625
# Loss after epoch 368: 2675.5, Total_loss : 1154942.125
# Loss after epoch 369: 2611.875, Total_loss : 1157554.0
# Loss after epoch 370: 2702.625, Total_loss : 1160256.625
# Loss after epoch 371: 2663.5, Total_loss : 1162920.125
# Loss after epoch 372: 2701.875, Total_loss : 1165622.0
# Loss after epoch 373: 2708.125, Total_loss : 1168330.125
# Loss after epoch 374: 2651.75, Total_loss : 1170981.875
# Loss after epoch 375: 2615.125, Total_loss : 1173597.0
# Loss after epoch 376: 2642.75, Total_loss : 1176239.75
# Loss after epoch 377: 2624.875, Total_loss : 1178864.625
# Loss after epoch 378: 2580.25, Total_loss : 1181444.875
# Loss after epoch 379: 121.0, Total_loss : 1181565.875
# Model 저장
# Loss after epoch 380: 2694.875, Total_loss : 1184260.75
# Loss after epoch 381: 2750.625, Total_loss : 1187011.375
# Loss after epoch 382: 2685.375, Total_loss : 1189696.75
# Loss after epoch 383: 2701.75, Total_loss : 1192398.5
# Loss after epoch 384: 2646.875, Total_loss : 1195045.375
# Loss after epoch 385: 2687.625, Total_loss : 1197733.0
# Loss after epoch 386: 2662.25, Total_loss : 1200395.25
# Loss after epoch 387: 2786.75, Total_loss : 1203182.0
# Loss after epoch 388: 2597.125, Total_loss : 1205779.125
# Loss after epoch 389: 2579.25, Total_loss : 1208358.375
# Loss after epoch 390: 2682.375, Total_loss : 1211040.75
# Loss after epoch 391: 2627.25, Total_loss : 1213668.0
# Loss after epoch 392: 2715.875, Total_loss : 1216383.875
# Loss after epoch 393: 2572.5, Total_loss : 1218956.375
# Loss after epoch 394: 2696.375, Total_loss : 1221652.75
# Loss after epoch 395: 2686.875, Total_loss : 1224339.625
# Loss after epoch 396: 2675.75, Total_loss : 1227015.375
# Loss after epoch 397: 2639.375, Total_loss : 1229654.75
# Loss after epoch 398: 2647.75, Total_loss : 1232302.5
# Loss after epoch 399: 2599.25, Total_loss : 1234901.75
# Loss after epoch 400: 2630.625, Total_loss : 1237532.375
# Loss after epoch 401: 2588.5, Total_loss : 1240120.875
# Loss after epoch 402: 2598.0, Total_loss : 1242718.875
# Loss after epoch 403: 117.25, Total_loss : 1242836.125
# Model 저장
# Loss after epoch 404: 2594.375, Total_loss : 1245430.5
# Loss after epoch 405: 109.25, Total_loss : 1245539.75
# Model 저장
# Loss after epoch 406: 2619.875, Total_loss : 1248159.625
# Loss after epoch 407: 2591.75, Total_loss : 1250751.375
# Loss after epoch 408: 2573.625, Total_loss : 1253325.0
# Loss after epoch 409: 2600.0, Total_loss : 1255925.0
# Loss after epoch 410: 2571.5, Total_loss : 1258496.5
# Loss after epoch 411: 2648.0, Total_loss : 1261144.5
# Loss after epoch 412: 2636.625, Total_loss : 1263781.125
# Loss after epoch 413: 2615.875, Total_loss : 1266397.0
# Loss after epoch 414: 140.125, Total_loss : 1266537.125
# Loss after epoch 415: 2646.625, Total_loss : 1269183.75
# Loss after epoch 416: 2737.75, Total_loss : 1271921.5
# Loss after epoch 417: 2600.625, Total_loss : 1274522.125
# Loss after epoch 418: 2696.75, Total_loss : 1277218.875
# Loss after epoch 419: 2657.625, Total_loss : 1279876.5
# Loss after epoch 420: 2580.375, Total_loss : 1282456.875
# Loss after epoch 421: 2540.375, Total_loss : 1284997.25
# Loss after epoch 422: 2613.25, Total_loss : 1287610.5
# Loss after epoch 423: 2575.375, Total_loss : 1290185.875
# Loss after epoch 424: 2587.5, Total_loss : 1292773.375
# Loss after epoch 425: 2519.0, Total_loss : 1295292.375
# Loss after epoch 426: 2622.25, Total_loss : 1297914.625
# Loss after epoch 427: 2644.5, Total_loss : 1300559.125
# Loss after epoch 428: 2564.875, Total_loss : 1303124.0
# Loss after epoch 429: 2606.75, Total_loss : 1305730.75
# Loss after epoch 430: 2632.375, Total_loss : 1308363.125
# Loss after epoch 431: 2647.0, Total_loss : 1311010.125
# Loss after epoch 432: 138.125, Total_loss : 1311148.25
# Loss after epoch 433: 2595.25, Total_loss : 1313743.5
# Loss after epoch 434: 2696.375, Total_loss : 1316439.875
# Loss after epoch 435: 2600.875, Total_loss : 1319040.75
# Loss after epoch 436: 2633.125, Total_loss : 1321673.875
# Loss after epoch 437: 2564.25, Total_loss : 1324238.125
# Loss after epoch 438: 2670.125, Total_loss : 1326908.25
# Loss after epoch 439: 2616.5, Total_loss : 1329524.75
# Loss after epoch 440: 2636.375, Total_loss : 1332161.125
# Loss after epoch 441: 2626.375, Total_loss : 1334787.5
# Loss after epoch 442: 2644.5, Total_loss : 1337432.0
# Loss after epoch 443: 2628.5, Total_loss : 1340060.5
# Loss after epoch 444: 2577.75, Total_loss : 1342638.25
# Loss after epoch 445: 2614.875, Total_loss : 1345253.125
# Loss after epoch 446: 2608.25, Total_loss : 1347861.375
# Loss after epoch 447: 2627.25, Total_loss : 1350488.625
# Loss after epoch 448: 2681.75, Total_loss : 1353170.375
# Loss after epoch 449: 2605.375, Total_loss : 1355775.75
# Loss after epoch 450: 2620.875, Total_loss : 1358396.625
# Loss after epoch 451: 2661.75, Total_loss : 1361058.375
# Loss after epoch 452: 2582.25, Total_loss : 1363640.625
# Loss after epoch 453: 2641.25, Total_loss : 1366281.875
# Loss after epoch 454: 2657.625, Total_loss : 1368939.5
# Loss after epoch 455: 2599.75, Total_loss : 1371539.25
# Loss after epoch 456: 2575.625, Total_loss : 1374114.875
# Loss after epoch 457: 2583.75, Total_loss : 1376698.625
# Loss after epoch 458: 2596.0, Total_loss : 1379294.625
# Loss after epoch 459: 2575.75, Total_loss : 1381870.375
# Loss after epoch 460: 2646.625, Total_loss : 1384517.0
# Loss after epoch 461: 2561.625, Total_loss : 1387078.625
# Loss after epoch 462: 2604.25, Total_loss : 1389682.875
# Loss after epoch 463: 2630.75, Total_loss : 1392313.625
# Loss after epoch 464: 2606.125, Total_loss : 1394919.75
# Loss after epoch 465: 2657.75, Total_loss : 1397577.5
# Loss after epoch 466: 2541.5, Total_loss : 1400119.0
# Loss after epoch 467: 2595.5, Total_loss : 1402714.5
# Loss after epoch 468: 2578.0, Total_loss : 1405292.5
# Loss after epoch 469: 2588.0, Total_loss : 1407880.5
# Loss after epoch 470: 2638.25, Total_loss : 1410518.75
# Loss after epoch 471: 2642.75, Total_loss : 1413161.5
# Loss after epoch 472: 2564.5, Total_loss : 1415726.0
# Loss after epoch 473: 133.625, Total_loss : 1415859.625
# Loss after epoch 474: 2605.25, Total_loss : 1418464.875
# Loss after epoch 475: 2532.5, Total_loss : 1420997.375
# Loss after epoch 476: 2561.0, Total_loss : 1423558.375
# Loss after epoch 477: 2602.875, Total_loss : 1426161.25
# Loss after epoch 478: 2606.5, Total_loss : 1428767.75
# Loss after epoch 479: 2603.75, Total_loss : 1431371.5
# Loss after epoch 480: 2582.625, Total_loss : 1433954.125
# Loss after epoch 481: 2570.875, Total_loss : 1436525.0
# Loss after epoch 482: 2587.375, Total_loss : 1439112.375
# Loss after epoch 483: 2558.875, Total_loss : 1441671.25
# Loss after epoch 484: 2514.375, Total_loss : 1444185.625
# Loss after epoch 485: 2609.0, Total_loss : 1446794.625
# Loss after epoch 486: 2554.75, Total_loss : 1449349.375
# Loss after epoch 487: 2630.5, Total_loss : 1451979.875
# Loss after epoch 488: 2536.625, Total_loss : 1454516.5
# Loss after epoch 489: 2549.0, Total_loss : 1457065.5
# Loss after epoch 490: 2536.375, Total_loss : 1459601.875
# Loss after epoch 491: 2580.75, Total_loss : 1462182.625
# Loss after epoch 492: 2631.625, Total_loss : 1464814.25
# Loss after epoch 493: 2570.25, Total_loss : 1467384.5
# Loss after epoch 494: 2549.5, Total_loss : 1469934.0
# Loss after epoch 495: 2507.875, Total_loss : 1472441.875
# Loss after epoch 496: 2609.875, Total_loss : 1475051.75
# Loss after epoch 497: 2573.75, Total_loss : 1477625.5
# Loss after epoch 498: 2597.875, Total_loss : 1480223.375
# Loss after epoch 499: 2588.125, Total_loss : 1482811.5
# Loss after epoch 500: 2561.75, Total_loss : 1485373.25
# Time passed: 0:00:05.289811

# %%
from gensim.models import Word2Vec

model = Word2Vec.load(model_dir + 'Word2Vec_Embedding_Model.model')

Name_li = train_df['cat_Name'].tolist() + test_df['cat_Name'].tolist()

arr = []
for Name in Name_li:
    arr.append(model[Name])

arr = np.array(arr)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
from sklearn.manifold import TSNE
tsne = TSNE(n_components=2, random_state = 22)
new_arr = tsne.fit_transform(arr)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:783: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:793: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   FutureWarning,

# %%
rows = len(train_df['cat_Name'].tolist())
train_arr = new_arr[:rows, :]
test_arr = new_arr[rows:, :]

# %%
train_df['X'] = train_arr[:, 0]
train_df['Y'] = train_arr[:, 1]

test_df['X'] = test_arr[:, 0]
test_df['Y'] = test_arr[:, 1]

# %%
fig, ax = plt.subplots(1,1, figsize=(8, 8))

ax.scatter(new_arr[:, 0], new_arr[:, 1], alpha = 0.7)

plt.show()

# %%
fig, ax = plt.subplots(1,1, figsize=(8, 8))

for i in train_df['Survived'].unique():
    df = train_df[train_df['Survived'] == i]

    ax.scatter(df['X'], df['Y'], alpha = 0.5, label = str(i))

plt.legend()
plt.show()

# %%
fig, ax = plt.subplots(1,1, figsize=(8, 8))

for i in train_df['Survived'].unique():
    df = train_df[train_df['Survived'] == i]

    ax.scatter(df['X'], df['Y'], alpha = 0.5, label = str(i))

ax.scatter(test_df['X'], test_df['Y'], alpha = 0.5, label = 'test_df')

plt.legend()
plt.show()
